# %%
from train import test

# test("checkpoints/2026-04-01 18:06:21.742996_normalize/residual_unet_epoch20.pt")
test("checkpoints/first_experiment/residual_unet_epoch20.pt")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 4
#       1 from train import test
#       2
#       3 # test("checkpoints/2026-04-01 18:06:21.742996_normalize/residual_unet_epoch20.pt")
# ----> 4 test("checkpoints/first_experiment/residual_unet_epoch20.pt")
#
# File ~/Desktop/diplomka/unet/train.py:156, in test(model_path)
#     153 model = ResidualUNet(in_channels=1, base_channels=8, logspace=False, normalize=False).to(device)
#     155 checkpoint = torch.load(model_path)
# --> 156 model.load_state_dict(checkpoint['model_state_dict'])
#     157 avg_loss, avg_psnr, examples = evaluate(model, val_loader, device, return_examples=1)
#     158 print("avg loss:", avg_loss)
#
# File ~/Desktop/diplomka/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:2639, in Module.load_state_dict(self, state_dict, strict, assign)
#    2631         error_msgs.insert(
# ...
